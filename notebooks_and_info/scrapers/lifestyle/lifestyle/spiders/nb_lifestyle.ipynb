# %%
import pandas as pd
from pathlib import Path
import sys
import scrapy
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from io import StringIO
from scrapy.crawler import CrawlerProcess
from pathlib import Path
import time
import datetime

# %% [markdown]
# # Constants

# %%
PATH_DATA = Path.cwd().parent.parent.parent.parent.parent / 'data'
PATH_DATA.exists()
# Out:
# True

# %%
PATH_SCRAPED = PATH_DATA / 'raw' / 'scraped'
PATH_SCRAPED.exists()
# Out:
# True

# %%
PATH_PREPROCESSED = PATH_DATA / 'preprocessed'
PATH_PREPROCESSED.exists()
# Out:
# True

# %%
PATH_ARCHAEA_ANNOTATION_HASHES = PATH_PREPROCESSED \
    / 'archaea' / 'annotation_hashes_e0.csv'
PATH_ARCHAEA_ANNOTATION_HASHES.exists()
# Out:
# True

# %% [markdown]
# # Data Extraction

# %%
df_archaea_name_url = pd.read_csv(PATH_SCRAPED / 'archaea_name_url.csv')
df_archaea_name_url
# Out:
#                                 name
# 0       ANME-2_cluster_archaeon_HR1/  \
# 1              Acidianus_ambivalens/
# 2               Acidianus_brierleyi/
# 3              Acidianus_hospitalis/
# 4                Acidianus_infernus/
# ...                              ...
# 1228  uncultured_Nitrososphaera_sp./
# 1229    uncultured_archaeon_A07HB70/
# 1230    uncultured_archaeon_A07HN63/
# 1231    uncultured_archaeon_A07HR60/
# 1232    uncultured_archaeon_A07HR67/
#
#                                                     url
# 0     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/ar...
# 1     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/ar...
# 2     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/ar...
# 3     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/ar...
# 4     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/ar...
# ...                                                 ...
# 1228  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/ar...
# 1229  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/ar...
# ...

# %%
archaea_names = list(df_archaea_name_url['name'].str[:-1])
archaea_names
# Out:
# ['ANME-2_cluster_archaeon_HR1',
#  'Acidianus_ambivalens',
#  'Acidianus_brierleyi',
#  'Acidianus_hospitalis',
#  'Acidianus_infernus',
#  'Acidianus_manzaensis',
#  'Acidianus_sp._HS-5',
#  'Acidianus_sp._RZ1',
#  'Acidianus_sulfidivorans',
#  'Acidilobus_saccharovorans',
#  'Acidilobus_sp._7A',
#  'Acidiplasma_aeolicum',
#  'Acidiplasma_cupricumulans',
#  'Acidiplasma_sp.',
#  'Acidiplasma_sp._MBA-1',
#  'Aciduliprofundum_sp._MAR08-339',
#  'Actinarchaeum_halophilum',
#  'Aeropyrum_camini',
#  'Aeropyrum_pernix',
#  'Aigarchaeota_archaeon_JGI_0000001-A7',
#  'Aigarchaeota_archaeon_JGI_0000001-H6',
#  'Aigarchaeota_archaeon_SCGC_AAA471-A16',
#  'Aigarchaeota_archaeon_SCGC_AAA471-B22',
#  'Aigarchaeota_archaeon_SCGC_AAA471-D15',
#  'Aigarchaeota_archaeon_SCGC_AAA471-E16',
#  'Aigarchaeota_archaeon_SCGC_AAA471-G05',
#  'Aigarchaeota_archaeon_SCGC_AAA471-I13',
#  'Aigarchaeota_archaeon_SCGC_AAA471-J07',
#  'Aigarchaeota_archaeon_SCGC_AAA471-J08',
#  'Archaeoglobus_fulgidus',
# ...

# %% [markdown]
# # Web Scraping
