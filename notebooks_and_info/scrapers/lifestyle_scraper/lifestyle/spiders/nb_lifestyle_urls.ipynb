# %%
import pandas as pd
from pathlib import Path
import sys
import scrapy
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from io import StringIO
from scrapy.crawler import CrawlerProcess
from pathlib import Path
import time
import datetime

# %% [markdown]
# # Settings

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Constants

# %%
PATH_DATA = Path.cwd().parent.parent.parent.parent.parent / 'data'
PATH_DATA.exists()
# Out:
# True

# %%
PATH_SCRAPED = PATH_DATA / 'raw' / 'scraped'
PATH_SCRAPED.exists()
# Out:
# True

# %%
PATH_PREPROCESSED = PATH_DATA / 'preprocessed'
PATH_PREPROCESSED.exists()
# Out:
# True

# %% [markdown]
# # Archaea

# %% [markdown]
# ## Data Extraction

# %%
df_archaea_name_url = pd.read_csv(PATH_SCRAPED / 'archaea_name_url.csv')
df_archaea_name_url
# Out:
#                                name
# 0       ANME-2_cluster_archaeon_HR1  \
# 1              Acidianus_ambivalens
# 2               Acidianus_brierleyi
# 3              Acidianus_hospitalis
# 4                Acidianus_infernus
# ...                             ...
# 1232  uncultured_Nitrososphaera_sp.
# 1233    uncultured_archaeon_A07HB70
# 1234    uncultured_archaeon_A07HN63
# 1235    uncultured_archaeon_A07HR60
# 1236    uncultured_archaeon_A07HR67
#
#                                                                                      url
# 0       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/ANME-2_cluster_archaeon_HR1/
# 1              https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_ambivalens/
# 2               https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_brierleyi/
# 3              https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_hospitalis/
# 4                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_infernus/
# ...                                                                                  ...
# 1232  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_Nitrososphaera_sp./
# 1233    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HB70/
# 1234    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HN63/
# 1235    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HR60/
# 1236    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HR67/
#
# [1237 rows x 2 columns]

# %%
df_archaea_name_formatting = df_archaea_name_url.copy()

# %% [markdown]
# ## Name formatting

# %% [markdown]
# ### GCM: 'sp.', 'spp.'

# %%
df_archaea_name_formatting['formatted_name_gcm'] = df_archaea_name_formatting['name'].apply(lambda x: x.split('sp.')[0] if ('sp.' in x) else x)
df_archaea_name_formatting['formatted_name_gcm'] = df_archaea_name_formatting['formatted_name_gcm'].str.replace('_', ' ')
df_archaea_name_formatting
# Out:
#                                name
# 0       ANME-2_cluster_archaeon_HR1  \
# 1              Acidianus_ambivalens
# 2               Acidianus_brierleyi
# 3              Acidianus_hospitalis
# 4                Acidianus_infernus
# ...                             ...
# 1232  uncultured_Nitrososphaera_sp.
# 1233    uncultured_archaeon_A07HB70
# 1234    uncultured_archaeon_A07HN63
# 1235    uncultured_archaeon_A07HR60
# 1236    uncultured_archaeon_A07HR67
#
#                                                                                      url
# 0       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/ANME-2_cluster_archaeon_HR1/  \
# 1              https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_ambivalens/
# 2               https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_brierleyi/
# 3              https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_hospitalis/
# 4                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_infernus/
# ...                                                                                  ...
# 1232  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_Nitrososphaera_sp./
# 1233    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HB70/
# 1234    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HN63/
# 1235    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HR60/
# 1236    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HR67/
#
#                formatted_name_gcm
# 0     ANME-2 cluster archaeon HR1
# 1            Acidianus ambivalens
# 2             Acidianus brierleyi
# 3            Acidianus hospitalis
# 4              Acidianus infernus
# ...                           ...
# 1232   uncultured Nitrososphaera
# 1233  uncultured archaeon A07HB70
# 1234  uncultured archaeon A07HN63
# 1235  uncultured archaeon A07HR60
# 1236  uncultured archaeon A07HR67
#
# [1237 rows x 3 columns]

# %%
df_archaea_name_formatting[df_archaea_name_formatting['name'].str.contains('sp(?!\.)', regex=True)].head()
# Out:
#                                           name
# 3                         Acidianus_hospitalis  \
# 38                     Caldisphaera_lagunensis
# 39                            Caldisphaera_sp.
# 71  Candidatus_Methanolliviera_sp._GoM_asphalt
# 78       Candidatus_Methanosphaera_massiliense
#
#                                                                                                 url
# 3                         https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_hospitalis/  \
# 38                     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Caldisphaera_lagunensis/
# 39                            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Caldisphaera_sp./
# 71  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Candidatus_Methanolliviera_sp._GoM_asphalt/
# 78       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Candidatus_Methanosphaera_massiliense/
#
#                        formatted_name_gcm
# 3                    Acidianus hospitalis
# 38                Caldisphaera lagunensis
# 39                          Caldisphaera
# 71            Candidatus Methanolliviera
# 78  Candidatus Methanosphaera massiliense

# %% [markdown]
# ### NCBI

# %%
df_archaea_name_formatting['formatted_name_ncbi'] = df_archaea_name_formatting['name'].str.replace('_', ' ')
df_archaea_name_formatting[:15]
# Out:
#                            name
# 0   ANME-2_cluster_archaeon_HR1  \
# 1          Acidianus_ambivalens
# 2           Acidianus_brierleyi
# 3          Acidianus_hospitalis
# 4            Acidianus_infernus
# 5          Acidianus_manzaensis
# 6            Acidianus_sp._HS-5
# 7             Acidianus_sp._RZ1
# 8       Acidianus_sulfidivorans
# 9     Acidilobus_saccharovorans
# 10            Acidilobus_sp._7A
# 11         Acidiplasma_aeolicum
# 12    Acidiplasma_cupricumulans
# 13              Acidiplasma_sp.
# 14        Acidiplasma_sp._MBA-1
#
#                                                                                  url
# 0   https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/ANME-2_cluster_archaeon_HR1/  \
# 1          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_ambivalens/
# 2           https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_brierleyi/
# 3          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_hospitalis/
# 4            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_infernus/
# 5          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_manzaensis/
# 6            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_sp._HS-5/
# 7             https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_sp._RZ1/
# 8       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_sulfidivorans/
# 9     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidilobus_saccharovorans/
# 10            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidilobus_sp._7A/
# 11         https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidiplasma_aeolicum/
# 12    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidiplasma_cupricumulans/
# 13              https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidiplasma_sp./
# 14        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidiplasma_sp._MBA-1/
#
#              formatted_name_gcm          formatted_name_ncbi
# 0   ANME-2 cluster archaeon HR1  ANME-2 cluster archaeon HR1
# 1          Acidianus ambivalens         Acidianus ambivalens
# 2           Acidianus brierleyi          Acidianus brierleyi
# 3          Acidianus hospitalis         Acidianus hospitalis
# 4            Acidianus infernus           Acidianus infernus
# 5          Acidianus manzaensis         Acidianus manzaensis
# 6                    Acidianus            Acidianus sp. HS-5
# 7                    Acidianus             Acidianus sp. RZ1
# 8       Acidianus sulfidivorans      Acidianus sulfidivorans
# 9     Acidilobus saccharovorans    Acidilobus saccharovorans
# 10                  Acidilobus             Acidilobus sp. 7A
# 11         Acidiplasma aeolicum         Acidiplasma aeolicum
# 12    Acidiplasma cupricumulans    Acidiplasma cupricumulans
# 13                 Acidiplasma               Acidiplasma sp.
# 14                 Acidiplasma         Acidiplasma sp. MBA-1

# %% [markdown]
# ### search_urls

# %%
base_url = 'https://gcm.wdcm.org/search?search='
df_archaea_name_formatting['url_gcm_search'] = base_url + df_archaea_name_formatting['formatted_name_gcm']
df_archaea_name_formatting[:15]
# Out:
#                            name
# 0   ANME-2_cluster_archaeon_HR1  \
# 1          Acidianus_ambivalens
# 2           Acidianus_brierleyi
# 3          Acidianus_hospitalis
# 4            Acidianus_infernus
# 5          Acidianus_manzaensis
# 6            Acidianus_sp._HS-5
# 7             Acidianus_sp._RZ1
# 8       Acidianus_sulfidivorans
# 9     Acidilobus_saccharovorans
# 10            Acidilobus_sp._7A
# 11         Acidiplasma_aeolicum
# 12    Acidiplasma_cupricumulans
# 13              Acidiplasma_sp.
# 14        Acidiplasma_sp._MBA-1
#
#                                                                                  url
# 0   https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/ANME-2_cluster_archaeon_HR1/  \
# 1          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_ambivalens/
# 2           https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_brierleyi/
# 3          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_hospitalis/
# 4            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_infernus/
# 5          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_manzaensis/
# 6            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_sp._HS-5/
# 7             https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_sp._RZ1/
# 8       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidianus_sulfidivorans/
# 9     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidilobus_saccharovorans/
# 10            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidilobus_sp._7A/
# 11         https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidiplasma_aeolicum/
# 12    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidiplasma_cupricumulans/
# 13              https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidiplasma_sp./
# 14        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Acidiplasma_sp._MBA-1/
#
#              formatted_name_gcm          formatted_name_ncbi
# 0   ANME-2 cluster archaeon HR1  ANME-2 cluster archaeon HR1  \
# 1          Acidianus ambivalens         Acidianus ambivalens
# 2           Acidianus brierleyi          Acidianus brierleyi
# 3          Acidianus hospitalis         Acidianus hospitalis
# 4            Acidianus infernus           Acidianus infernus
# 5          Acidianus manzaensis         Acidianus manzaensis
# 6                    Acidianus            Acidianus sp. HS-5
# 7                    Acidianus             Acidianus sp. RZ1
# 8       Acidianus sulfidivorans      Acidianus sulfidivorans
# 9     Acidilobus saccharovorans    Acidilobus saccharovorans
# 10                  Acidilobus             Acidilobus sp. 7A
# 11         Acidiplasma aeolicum         Acidiplasma aeolicum
# 12    Acidiplasma cupricumulans    Acidiplasma cupricumulans
# 13                 Acidiplasma               Acidiplasma sp.
# 14                 Acidiplasma         Acidiplasma sp. MBA-1
#
#                                                     url_gcm_search
# 0   https://gcm.wdcm.org/search?search=ANME-2 cluster archaeon HR1
# 1          https://gcm.wdcm.org/search?search=Acidianus ambivalens
# 2           https://gcm.wdcm.org/search?search=Acidianus brierleyi
# 3          https://gcm.wdcm.org/search?search=Acidianus hospitalis
# 4            https://gcm.wdcm.org/search?search=Acidianus infernus
# 5          https://gcm.wdcm.org/search?search=Acidianus manzaensis
# 6                    https://gcm.wdcm.org/search?search=Acidianus
# 7                    https://gcm.wdcm.org/search?search=Acidianus
# 8       https://gcm.wdcm.org/search?search=Acidianus sulfidivorans
# 9     https://gcm.wdcm.org/search?search=Acidilobus saccharovorans
# 10                  https://gcm.wdcm.org/search?search=Acidilobus
# 11         https://gcm.wdcm.org/search?search=Acidiplasma aeolicum
# 12    https://gcm.wdcm.org/search?search=Acidiplasma cupricumulans
# 13                 https://gcm.wdcm.org/search?search=Acidiplasma
# 14                 https://gcm.wdcm.org/search?search=Acidiplasma

# %%
df_archaea_name_formatting['url_gcm_isolation_src'] = base_url + df_archaea_name_formatting['formatted_name_gcm'].str.strip() + '&list=isolate'
df_archaea_name_formatting[15:]
# Out:
#                                       name
# 15          Aciduliprofundum_sp._MAR08-339  \
# 16                Actinarchaeum_halophilum
# 17                        Aeropyrum_camini
# 18                        Aeropyrum_pernix
# 19    Aigarchaeota_archaeon_JGI_0000001-A7
# ...                                    ...
# 1232         uncultured_Nitrososphaera_sp.
# 1233           uncultured_archaeon_A07HB70
# 1234           uncultured_archaeon_A07HN63
# 1235           uncultured_archaeon_A07HR60
# 1236           uncultured_archaeon_A07HR67
#
#                                                                                             url
# 15          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Aciduliprofundum_sp._MAR08-339/  \
# 16                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Actinarchaeum_halophilum/
# 17                        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Aeropyrum_camini/
# 18                        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Aeropyrum_pernix/
# 19    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/Aigarchaeota_archaeon_JGI_0000001-A7/
# ...                                                                                         ...
# 1232         https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_Nitrososphaera_sp./
# 1233           https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HB70/
# 1234           https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HN63/
# 1235           https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HR60/
# 1236           https://ftp.ncbi.nlm.nih.gov/genomes/refseq/archaea/uncultured_archaeon_A07HR67/
#
#                         formatted_name_gcm
# 15                       Aciduliprofundum   \
# 16                Actinarchaeum halophilum
# 17                        Aeropyrum camini
# 18                        Aeropyrum pernix
# 19    Aigarchaeota archaeon JGI 0000001-A7
# ...                                    ...
# 1232            uncultured Nitrososphaera
# 1233           uncultured archaeon A07HB70
# 1234           uncultured archaeon A07HN63
# 1235           uncultured archaeon A07HR60
# 1236           uncultured archaeon A07HR67
#
#                        formatted_name_ncbi
# 15          Aciduliprofundum sp. MAR08-339  \
# 16                Actinarchaeum halophilum
# 17                        Aeropyrum camini
# 18                        Aeropyrum pernix
# 19    Aigarchaeota archaeon JGI 0000001-A7
# ...                                    ...
# 1232         uncultured Nitrososphaera sp.
# 1233           uncultured archaeon A07HB70
# 1234           uncultured archaeon A07HN63
# 1235           uncultured archaeon A07HR60
# 1236           uncultured archaeon A07HR67
#
#                                                                url_gcm_search
# 15                       https://gcm.wdcm.org/search?search=Aciduliprofundum   \
# 16                https://gcm.wdcm.org/search?search=Actinarchaeum halophilum
# 17                        https://gcm.wdcm.org/search?search=Aeropyrum camini
# 18                        https://gcm.wdcm.org/search?search=Aeropyrum pernix
# 19    https://gcm.wdcm.org/search?search=Aigarchaeota archaeon JGI 0000001-A7
# ...                                                                       ...
# 1232            https://gcm.wdcm.org/search?search=uncultured Nitrososphaera
# 1233           https://gcm.wdcm.org/search?search=uncultured archaeon A07HB70
# 1234           https://gcm.wdcm.org/search?search=uncultured archaeon A07HN63
# 1235           https://gcm.wdcm.org/search?search=uncultured archaeon A07HR60
# 1236           https://gcm.wdcm.org/search?search=uncultured archaeon A07HR67
#
#                                                                      url_gcm_isolation_src
# 15                        https://gcm.wdcm.org/search?search=Aciduliprofundum&list=isolate
# 16                https://gcm.wdcm.org/search?search=Actinarchaeum halophilum&list=isolate
# 17                        https://gcm.wdcm.org/search?search=Aeropyrum camini&list=isolate
# 18                        https://gcm.wdcm.org/search?search=Aeropyrum pernix&list=isolate
# 19    https://gcm.wdcm.org/search?search=Aigarchaeota archaeon JGI 0000001-A7&list=isolate
# ...                                                                                    ...
# 1232             https://gcm.wdcm.org/search?search=uncultured Nitrososphaera&list=isolate
# 1233           https://gcm.wdcm.org/search?search=uncultured archaeon A07HB70&list=isolate
# 1234           https://gcm.wdcm.org/search?search=uncultured archaeon A07HN63&list=isolate
# 1235           https://gcm.wdcm.org/search?search=uncultured archaeon A07HR60&list=isolate
# 1236           https://gcm.wdcm.org/search?search=uncultured archaeon A07HR67&list=isolate
#
# [1222 rows x 6 columns]

# %%
df_archaea_name_formatting.columns
# Out:
# Index(['name', 'url', 'formatted_name_gcm', 'formatted_name_ncbi',
#        'url_gcm_search', 'url_gcm_isolation_src'],
#       dtype='object')

# %% [markdown]
# ### save

# %%
# df_archaea_name_formatting.to_csv(PATH_PREPROCESSED / 'archaea' / 'archaea_name_formatting.csv', index=False)

# %% [markdown]
# # Bacteria

# %% [markdown]
# ## Data Extraction

# %%
df_bacteria_name_url = pd.read_csv(PATH_SCRAPED / 'bacteria_name_url.csv')
df_bacteria_name_url
# Out:
#                                        name
# 0               Abditibacterium_utsteinense  \
# 1                     Abiotrophia_defectiva
# 2                           Abiotrophia_sp.
# 3                 Abiotrophia_sp._HMSC24B09
# 4                          Absicoccus_porci
# ...                                     ...
# 52904  zeta_proteobacterium_SCGC_AB-137-J06
# 52905  zeta_proteobacterium_SCGC_AB-602-C20
# 52906  zeta_proteobacterium_SCGC_AB-602-E04
# 52907  zeta_proteobacterium_SCGC_AB-604-B04
# 52908  zeta_proteobacterium_SCGC_AB-604-O16
#
#                                                                                               url
# 0               https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 1                     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_defectiva/
# 2                           https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp./
# 3                 https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp._HMSC24B09/
# 4                          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_porci/
# ...                                                                                           ...
# 52904  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-137-J06/
# 52905  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-602-C20/
# 52906  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-602-E04/
# 52907  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-604-B04/
# 52908  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-604-O16/
#
# [52909 rows x 2 columns]

# %%
df_bacteria_name_formatting = df_bacteria_name_url.copy()

# %% [markdown]
# ## Name formatting

# %% [markdown]
# ### GCM: 'sp.', 'spp.'

# %%
df_bacteria_name_formatting['formatted_name_gcm'] = df_bacteria_name_formatting['name'].apply(lambda x: x.split('sp.')[0] if ('sp.' in x) else x)
df_bacteria_name_formatting['formatted_name_gcm'] = df_bacteria_name_formatting['formatted_name_gcm'].str.replace('_', ' ')
df_bacteria_name_formatting
# Out:
#                                        name
# 0               Abditibacterium_utsteinense  \
# 1                     Abiotrophia_defectiva
# 2                           Abiotrophia_sp.
# 3                 Abiotrophia_sp._HMSC24B09
# 4                          Absicoccus_porci
# ...                                     ...
# 52904  zeta_proteobacterium_SCGC_AB-137-J06
# 52905  zeta_proteobacterium_SCGC_AB-602-C20
# 52906  zeta_proteobacterium_SCGC_AB-602-E04
# 52907  zeta_proteobacterium_SCGC_AB-604-B04
# 52908  zeta_proteobacterium_SCGC_AB-604-O16
#
#                                                                                               url
# 0               https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/  \
# 1                     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_defectiva/
# 2                           https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp./
# 3                 https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp._HMSC24B09/
# 4                          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_porci/
# ...                                                                                           ...
# 52904  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-137-J06/
# 52905  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-602-C20/
# 52906  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-602-E04/
# 52907  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-604-B04/
# 52908  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-604-O16/
#
#                          formatted_name_gcm
# 0               Abditibacterium utsteinense
# 1                     Abiotrophia defectiva
# 2                              Abiotrophia
# 3                              Abiotrophia
# 4                          Absicoccus porci
# ...                                     ...
# 52904  zeta proteobacterium SCGC AB-137-J06
# 52905  zeta proteobacterium SCGC AB-602-C20
# 52906  zeta proteobacterium SCGC AB-602-E04
# 52907  zeta proteobacterium SCGC AB-604-B04
# 52908  zeta proteobacterium SCGC AB-604-O16
#
# [52909 rows x 3 columns]

# %% [markdown]
# ### NCBI

# %%
df_bacteria_name_formatting['formatted_name_ncbi'] = df_bacteria_name_formatting['name'].str.replace('_', ' ')
df_bacteria_name_formatting[:15]
# Out:
#                            name
# 0   Abditibacterium_utsteinense  \
# 1         Abiotrophia_defectiva
# 2               Abiotrophia_sp.
# 3     Abiotrophia_sp._HMSC24B09
# 4              Absicoccus_porci
# 5                Absicoccus_sp.
# 6    Absicoccus_sp._CLA-KB-P134
# 7          Absiella_sp._AM09-45
# 8          Absiella_sp._AM09-50
# 9          Absiella_sp._AM10-20
# 10          Absiella_sp._AM22-9
# 11         Absiella_sp._AM27-20
# 12         Absiella_sp._AM29-15
# 13        Absiella_sp._AM54-8XD
# 14             Abyssalbus_ytuae
#
#                                                                                   url
# 0   https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/  \
# 1         https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_defectiva/
# 2               https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp./
# 3     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp._HMSC24B09/
# 4              https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_porci/
# 5                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_sp./
# 6    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_sp._CLA-KB-P134/
# 7          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM09-45/
# 8          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM09-50/
# 9          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM10-20/
# 10          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM22-9/
# 11         https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM27-20/
# 12         https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM29-15/
# 13        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM54-8XD/
# 14             https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abyssalbus_ytuae/
#
#              formatted_name_gcm          formatted_name_ncbi
# 0   Abditibacterium utsteinense  Abditibacterium utsteinense
# 1         Abiotrophia defectiva        Abiotrophia defectiva
# 2                  Abiotrophia               Abiotrophia sp.
# 3                  Abiotrophia     Abiotrophia sp. HMSC24B09
# 4              Absicoccus porci             Absicoccus porci
# 5                   Absicoccus                Absicoccus sp.
# 6                   Absicoccus    Absicoccus sp. CLA-KB-P134
# 7                     Absiella          Absiella sp. AM09-45
# 8                     Absiella          Absiella sp. AM09-50
# 9                     Absiella          Absiella sp. AM10-20
# 10                    Absiella           Absiella sp. AM22-9
# 11                    Absiella          Absiella sp. AM27-20
# 12                    Absiella          Absiella sp. AM29-15
# 13                    Absiella         Absiella sp. AM54-8XD
# 14             Abyssalbus ytuae             Abyssalbus ytuae

# %% [markdown]
# ### search_urls

# %%
base_url = 'https://gcm.wdcm.org/search?search='
df_bacteria_name_formatting['url_gcm_search'] = base_url + df_bacteria_name_formatting['formatted_name_gcm']
df_bacteria_name_formatting[:15]
# Out:
#                            name
# 0   Abditibacterium_utsteinense  \
# 1         Abiotrophia_defectiva
# 2               Abiotrophia_sp.
# 3     Abiotrophia_sp._HMSC24B09
# 4              Absicoccus_porci
# 5                Absicoccus_sp.
# 6    Absicoccus_sp._CLA-KB-P134
# 7          Absiella_sp._AM09-45
# 8          Absiella_sp._AM09-50
# 9          Absiella_sp._AM10-20
# 10          Absiella_sp._AM22-9
# 11         Absiella_sp._AM27-20
# 12         Absiella_sp._AM29-15
# 13        Absiella_sp._AM54-8XD
# 14             Abyssalbus_ytuae
#
#                                                                                   url
# 0   https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/  \
# 1         https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_defectiva/
# 2               https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp./
# 3     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp._HMSC24B09/
# 4              https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_porci/
# 5                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_sp./
# 6    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_sp._CLA-KB-P134/
# 7          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM09-45/
# 8          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM09-50/
# 9          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM10-20/
# 10          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM22-9/
# 11         https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM27-20/
# 12         https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM29-15/
# 13        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absiella_sp._AM54-8XD/
# 14             https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abyssalbus_ytuae/
#
#              formatted_name_gcm          formatted_name_ncbi
# 0   Abditibacterium utsteinense  Abditibacterium utsteinense  \
# 1         Abiotrophia defectiva        Abiotrophia defectiva
# 2                  Abiotrophia               Abiotrophia sp.
# 3                  Abiotrophia     Abiotrophia sp. HMSC24B09
# 4              Absicoccus porci             Absicoccus porci
# 5                   Absicoccus                Absicoccus sp.
# 6                   Absicoccus    Absicoccus sp. CLA-KB-P134
# 7                     Absiella          Absiella sp. AM09-45
# 8                     Absiella          Absiella sp. AM09-50
# 9                     Absiella          Absiella sp. AM10-20
# 10                    Absiella           Absiella sp. AM22-9
# 11                    Absiella          Absiella sp. AM27-20
# 12                    Absiella          Absiella sp. AM29-15
# 13                    Absiella         Absiella sp. AM54-8XD
# 14             Abyssalbus ytuae             Abyssalbus ytuae
#
#                                                     url_gcm_search
# 0   https://gcm.wdcm.org/search?search=Abditibacterium utsteinense
# 1         https://gcm.wdcm.org/search?search=Abiotrophia defectiva
# 2                  https://gcm.wdcm.org/search?search=Abiotrophia
# 3                  https://gcm.wdcm.org/search?search=Abiotrophia
# 4              https://gcm.wdcm.org/search?search=Absicoccus porci
# 5                   https://gcm.wdcm.org/search?search=Absicoccus
# 6                   https://gcm.wdcm.org/search?search=Absicoccus
# 7                     https://gcm.wdcm.org/search?search=Absiella
# 8                     https://gcm.wdcm.org/search?search=Absiella
# 9                     https://gcm.wdcm.org/search?search=Absiella
# 10                    https://gcm.wdcm.org/search?search=Absiella
# 11                    https://gcm.wdcm.org/search?search=Absiella
# 12                    https://gcm.wdcm.org/search?search=Absiella
# 13                    https://gcm.wdcm.org/search?search=Absiella
# 14             https://gcm.wdcm.org/search?search=Abyssalbus ytuae

# %%
df_bacteria_name_formatting['url_gcm_isolation_src'] = base_url + df_bacteria_name_formatting['formatted_name_gcm'].str.strip() + '&list=isolate'
df_bacteria_name_formatting[15:]
# Out:
#                                        name
# 15                    Abyssibacter_profundi  \
# 16                         Abyssibacter_sp.
# 17               Abyssibius_alkaniclasticus
# 18                       Abyssicoccus_albus
# 19              Abyssisolibacter_fermentans
# ...                                     ...
# 52904  zeta_proteobacterium_SCGC_AB-137-J06
# 52905  zeta_proteobacterium_SCGC_AB-602-C20
# 52906  zeta_proteobacterium_SCGC_AB-602-E04
# 52907  zeta_proteobacterium_SCGC_AB-604-B04
# 52908  zeta_proteobacterium_SCGC_AB-604-O16
#
#                                                                                               url
# 15                    https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abyssibacter_profundi/  \
# 16                         https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abyssibacter_sp./
# 17               https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abyssibius_alkaniclasticus/
# 18                       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abyssicoccus_albus/
# 19              https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abyssisolibacter_fermentans/
# ...                                                                                           ...
# 52904  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-137-J06/
# 52905  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-602-C20/
# 52906  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-602-E04/
# 52907  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-604-B04/
# 52908  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-604-O16/
#
#                          formatted_name_gcm
# 15                    Abyssibacter profundi  \
# 16                            Abyssibacter
# 17               Abyssibius alkaniclasticus
# 18                       Abyssicoccus albus
# 19              Abyssisolibacter fermentans
# ...                                     ...
# 52904  zeta proteobacterium SCGC AB-137-J06
# 52905  zeta proteobacterium SCGC AB-602-C20
# 52906  zeta proteobacterium SCGC AB-602-E04
# 52907  zeta proteobacterium SCGC AB-604-B04
# 52908  zeta proteobacterium SCGC AB-604-O16
#
#                         formatted_name_ncbi
# 15                    Abyssibacter profundi  \
# 16                         Abyssibacter sp.
# 17               Abyssibius alkaniclasticus
# 18                       Abyssicoccus albus
# 19              Abyssisolibacter fermentans
# ...                                     ...
# 52904  zeta proteobacterium SCGC AB-137-J06
# 52905  zeta proteobacterium SCGC AB-602-C20
# 52906  zeta proteobacterium SCGC AB-602-E04
# 52907  zeta proteobacterium SCGC AB-604-B04
# 52908  zeta proteobacterium SCGC AB-604-O16
#
#                                                                 url_gcm_search
# 15                    https://gcm.wdcm.org/search?search=Abyssibacter profundi  \
# 16                            https://gcm.wdcm.org/search?search=Abyssibacter
# 17               https://gcm.wdcm.org/search?search=Abyssibius alkaniclasticus
# 18                       https://gcm.wdcm.org/search?search=Abyssicoccus albus
# 19              https://gcm.wdcm.org/search?search=Abyssisolibacter fermentans
# ...                                                                        ...
# 52904  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-137-J06
# 52905  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-C20
# 52906  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-E04
# 52907  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-B04
# 52908  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-O16
#
#                                                                       url_gcm_isolation_src
# 15                    https://gcm.wdcm.org/search?search=Abyssibacter profundi&list=isolate
# 16                             https://gcm.wdcm.org/search?search=Abyssibacter&list=isolate
# 17               https://gcm.wdcm.org/search?search=Abyssibius alkaniclasticus&list=isolate
# 18                       https://gcm.wdcm.org/search?search=Abyssicoccus albus&list=isolate
# 19              https://gcm.wdcm.org/search?search=Abyssisolibacter fermentans&list=isolate
# ...                                                                                     ...
# 52904  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-137-J06&list=isolate
# 52905  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-C20&list=isolate
# 52906  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-E04&list=isolate
# 52907  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-B04&list=isolate
# 52908  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-O16&list=isolate
#
# [52894 rows x 6 columns]

# %%
df_bacteria_name_formatting.columns
# Out:
# Index(['name', 'url', 'formatted_name_gcm', 'formatted_name_ncbi',
#        'url_gcm_search', 'url_gcm_isolation_src'],
#       dtype='object')

# %% [markdown]
# ### No duplicates

# %%
df_bacteria_name_formatting = pd.read_csv(PATH_PREPROCESSED / 'bacteria' / 'bacteria_name_formatting.csv')
df_bacteria_name_formatting
# Out:
#                                        name
# 0               Abditibacterium_utsteinense  \
# 1                     Abiotrophia_defectiva
# 2                           Abiotrophia_sp.
# 3                 Abiotrophia_sp._HMSC24B09
# 4                          Absicoccus_porci
# ...                                     ...
# 52904  zeta_proteobacterium_SCGC_AB-137-J06
# 52905  zeta_proteobacterium_SCGC_AB-602-C20
# 52906  zeta_proteobacterium_SCGC_AB-602-E04
# 52907  zeta_proteobacterium_SCGC_AB-604-B04
# 52908  zeta_proteobacterium_SCGC_AB-604-O16
#
#                                                                                               url
# 0               https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/  \
# 1                     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_defectiva/
# 2                           https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp./
# 3                 https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp._HMSC24B09/
# 4                          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_porci/
# ...                                                                                           ...
# 52904  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-137-J06/
# 52905  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-602-C20/
# 52906  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-602-E04/
# 52907  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-604-B04/
# 52908  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-604-O16/
#
#                          formatted_name_gcm
# 0               Abditibacterium utsteinense  \
# 1                     Abiotrophia defectiva
# 2                              Abiotrophia
# 3                              Abiotrophia
# 4                          Absicoccus porci
# ...                                     ...
# 52904  zeta proteobacterium SCGC AB-137-J06
# 52905  zeta proteobacterium SCGC AB-602-C20
# 52906  zeta proteobacterium SCGC AB-602-E04
# 52907  zeta proteobacterium SCGC AB-604-B04
# 52908  zeta proteobacterium SCGC AB-604-O16
#
#                         formatted_name_ncbi
# 0               Abditibacterium utsteinense  \
# 1                     Abiotrophia defectiva
# 2                           Abiotrophia sp.
# 3                 Abiotrophia sp. HMSC24B09
# 4                          Absicoccus porci
# ...                                     ...
# 52904  zeta proteobacterium SCGC AB-137-J06
# 52905  zeta proteobacterium SCGC AB-602-C20
# 52906  zeta proteobacterium SCGC AB-602-E04
# 52907  zeta proteobacterium SCGC AB-604-B04
# 52908  zeta proteobacterium SCGC AB-604-O16
#
#                                                                 url_gcm_search
# 0               https://gcm.wdcm.org/search?search=Abditibacterium utsteinense  \
# 1                     https://gcm.wdcm.org/search?search=Abiotrophia defectiva
# 2                              https://gcm.wdcm.org/search?search=Abiotrophia
# 3                              https://gcm.wdcm.org/search?search=Abiotrophia
# 4                          https://gcm.wdcm.org/search?search=Absicoccus porci
# ...                                                                        ...
# 52904  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-137-J06
# 52905  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-C20
# 52906  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-E04
# 52907  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-B04
# 52908  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-O16
#
#                                                                       url_gcm_isolation_src
# 0               https://gcm.wdcm.org/search?search=Abditibacterium utsteinense&list=isolate
# 1                     https://gcm.wdcm.org/search?search=Abiotrophia defectiva&list=isolate
# 2                               https://gcm.wdcm.org/search?search=Abiotrophia&list=isolate
# 3                               https://gcm.wdcm.org/search?search=Abiotrophia&list=isolate
# 4                          https://gcm.wdcm.org/search?search=Absicoccus porci&list=isolate
# ...                                                                                     ...
# 52904  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-137-J06&list=isolate
# 52905  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-C20&list=isolate
# 52906  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-E04&list=isolate
# 52907  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-B04&list=isolate
# 52908  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-O16&list=isolate
#
# [52909 rows x 6 columns]

# %%
df_bacteria_name_formatting_no_duplicates = df_bacteria_name_formatting.drop_duplicates(subset=['url_gcm_isolation_src'], keep='first')
df_bacteria_name_formatting_no_duplicates
# Out:
#                                        name
# 0               Abditibacterium_utsteinense  \
# 1                     Abiotrophia_defectiva
# 2                           Abiotrophia_sp.
# 4                          Absicoccus_porci
# 5                            Absicoccus_sp.
# ...                                     ...
# 52904  zeta_proteobacterium_SCGC_AB-137-J06
# 52905  zeta_proteobacterium_SCGC_AB-602-C20
# 52906  zeta_proteobacterium_SCGC_AB-602-E04
# 52907  zeta_proteobacterium_SCGC_AB-604-B04
# 52908  zeta_proteobacterium_SCGC_AB-604-O16
#
#                                                                                               url
# 0               https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/  \
# 1                     https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_defectiva/
# 2                           https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp./
# 4                          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_porci/
# 5                            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_sp./
# ...                                                                                           ...
# 52904  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-137-J06/
# 52905  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-602-C20/
# 52906  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-602-E04/
# 52907  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-604-B04/
# 52908  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/zeta_proteobacterium_SCGC_AB-604-O16/
#
#                          formatted_name_gcm
# 0               Abditibacterium utsteinense  \
# 1                     Abiotrophia defectiva
# 2                              Abiotrophia
# 4                          Absicoccus porci
# 5                               Absicoccus
# ...                                     ...
# 52904  zeta proteobacterium SCGC AB-137-J06
# 52905  zeta proteobacterium SCGC AB-602-C20
# 52906  zeta proteobacterium SCGC AB-602-E04
# 52907  zeta proteobacterium SCGC AB-604-B04
# 52908  zeta proteobacterium SCGC AB-604-O16
#
#                         formatted_name_ncbi
# 0               Abditibacterium utsteinense  \
# 1                     Abiotrophia defectiva
# 2                           Abiotrophia sp.
# 4                          Absicoccus porci
# 5                            Absicoccus sp.
# ...                                     ...
# 52904  zeta proteobacterium SCGC AB-137-J06
# 52905  zeta proteobacterium SCGC AB-602-C20
# 52906  zeta proteobacterium SCGC AB-602-E04
# 52907  zeta proteobacterium SCGC AB-604-B04
# 52908  zeta proteobacterium SCGC AB-604-O16
#
#                                                                 url_gcm_search
# 0               https://gcm.wdcm.org/search?search=Abditibacterium utsteinense  \
# 1                     https://gcm.wdcm.org/search?search=Abiotrophia defectiva
# 2                              https://gcm.wdcm.org/search?search=Abiotrophia
# 4                          https://gcm.wdcm.org/search?search=Absicoccus porci
# 5                               https://gcm.wdcm.org/search?search=Absicoccus
# ...                                                                        ...
# 52904  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-137-J06
# 52905  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-C20
# 52906  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-E04
# 52907  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-B04
# 52908  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-O16
#
#                                                                       url_gcm_isolation_src
# 0               https://gcm.wdcm.org/search?search=Abditibacterium utsteinense&list=isolate
# 1                     https://gcm.wdcm.org/search?search=Abiotrophia defectiva&list=isolate
# 2                               https://gcm.wdcm.org/search?search=Abiotrophia&list=isolate
# 4                          https://gcm.wdcm.org/search?search=Absicoccus porci&list=isolate
# 5                                https://gcm.wdcm.org/search?search=Absicoccus&list=isolate
# ...                                                                                     ...
# 52904  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-137-J06&list=isolate
# 52905  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-C20&list=isolate
# 52906  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-602-E04&list=isolate
# 52907  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-B04&list=isolate
# 52908  https://gcm.wdcm.org/search?search=zeta proteobacterium SCGC AB-604-O16&list=isolate
#
# [23147 rows x 6 columns]

# %% [markdown]
# ### save

# %%
# df_bacteria_name_formatting.to_csv(PATH_PREPROCESSED / 'bacteria' / 'bacteria_name_formatting.csv', index=False)

# %%
# df_bacteria_name_formatting_no_duplicates.to_csv(PATH_PREPROCESSED / 'bacteria' / 'bacteria_name_formatting_no_duplicates.csv', index=False)
