# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.lines import Line2D
import seaborn as sns

# %% [markdown]
# # Constants

# %%
# Show the full content of each cell
pd.options.display.max_colwidth = None

# Show all columns in the DataFrame
pd.options.display.max_columns = None

# %%
PATH_DATA = Path.cwd().parent.parent.parent / 'data'
PATH_DATA.exists()
# Out:
# True

# %%
PATH_SCRAPED = PATH_DATA / "raw" / "scraped"
PATH_SCRAPED.exists()
# Out:
# True

# %%
PATH_RESULTS_BACTERIA = (PATH_DATA / "results" / "bacteria")
PATH_RESULTS_BACTERIA.exists()
# Out:
# True

# %%
PATH_TAXONOMY_BACTERIA = (PATH_SCRAPED / "bacteria" / "taxonomy")
PATH_TAXONOMY_BACTERIA.exists()
# Out:
# True

# %% [markdown]
# # Bacteria

# %%
df_bacteria_0_35k = pd.read_csv(PATH_RESULTS_BACTERIA / 'mfa_bacteria_0_35000.csv', sep=';', dtype=str)
df_bacteria_0_35k
# Out:
#                                 name  \
# 0        Abditibacterium_utsteinense
# 1        Abditibacterium_utsteinense
# 2        Abditibacterium_utsteinense
# 3        Abditibacterium_utsteinense
# 4        Abditibacterium_utsteinense
# ...                              ...
# 5539259          PVC_group_bacterium
# 5539260          PVC_group_bacterium
# 5539261          PVC_group_bacterium
# 5539262          PVC_group_bacterium
# 5539263          PVC_group_bacterium
#
#                                                                                        url  \
# 0        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 1        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 2        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 3        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 4        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# ...                                                                                    ...
# 5539259          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/PVC_group_bacterium/
# 5539260          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/PVC_group_bacterium/
# 5539261          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/PVC_group_bacterium/
# 5539262          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/PVC_group_bacterium/
# 5539263          https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/PVC_group_bacterium/
#
#                               sequence seq_length          GC_content      Q  \
# 0          abditibacterium_utsteinense    3606331  0,5426839632856774  -20,0
# 1          abditibacterium_utsteinense    3606331  0,5426839632856774  -19,0
# 2          abditibacterium_utsteinense    3606331  0,5426839632856774  -18,0
# 3          abditibacterium_utsteinense    3606331  0,5426839632856774  -17,0
# 4          abditibacterium_utsteinense    3606331  0,5426839632856774  -16,0
# ...                                ...        ...                 ...    ...
# 5539259  pvc_group_bacterium_segment_3    1460619  0,6363076202623682   16,0
# 5539260  pvc_group_bacterium_segment_3    1460619  0,6363076202623682   17,0
# 5539261  pvc_group_bacterium_segment_3    1460619  0,6363076202623682   18,0
# 5539262  pvc_group_bacterium_segment_3    1460619  0,6363076202623682   19,0
# 5539263  pvc_group_bacterium_segment_3    1460619  0,6363076202623682   20,0
#
#                       Tau(Q)                D(Q)           r_squared  \
# 0         -72,66465514634189  3,4602216736353277  0,9698146394684455
# 1         -69,06562170824506   3,453281085412253  0,9700241704080936
# 2          -65,4663970739676  3,4455998459982946  0,9702559315728465
# 3        -61,866949855097616   3,437052769727645  0,9705136434109122
# 4        -58,267243922844344  3,4274849366379025  0,9708019026058612
# ...                      ...                 ...                 ...
# 5539259   21,465132664000123  1,4310088442666749  0,9976833291538687
# 5539260    22,81927140198009  1,4262044626237556  0,9976479303763938
# 5539261   24,172991159683413  1,4219406564519654  0,9976172541412566
# 5539262   25,526317899456267  1,4181287721920148  0,9975905129762491
# 5539263    26,87927288206122   1,414698572740064   0,997567073604625
#
#                    Delta_Dq
# 0         2,136053987504341
# 1         2,136053987504341
# 2         2,136053987504341
# 3         2,136053987504341
# 4         2,136053987504341
# ...                     ...
# 5539259  1,4348619472405753
# 5539260  1,4348619472405753
# 5539261  1,4348619472405753
# 5539262  1,4348619472405753
# 5539263  1,4348619472405753
#
# [5539264 rows x 10 columns]

# %%
df_bacteria_35k_52k = pd.read_csv(PATH_RESULTS_BACTERIA / 'mfa_bacteria_35000_52909.csv', sep=';', dtype=str)
df_bacteria_35k_52k
# Out:
#                                 name  \
# 0        Pseudodesulfovibrio_indicus
# 1        Pseudodesulfovibrio_indicus
# 2        Pseudodesulfovibrio_indicus
# 3        Pseudodesulfovibrio_indicus
# 4        Pseudodesulfovibrio_indicus
# ...                              ...
# 3417591                Zymomonas_sp.
# 3417592                Zymomonas_sp.
# 3417593                Zymomonas_sp.
# 3417594                Zymomonas_sp.
# 3417595                Zymomonas_sp.
#
#                                                                                        url  \
# 0        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Pseudodesulfovibrio_indicus/
# 1        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Pseudodesulfovibrio_indicus/
# 2        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Pseudodesulfovibrio_indicus/
# 3        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Pseudodesulfovibrio_indicus/
# 4        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Pseudodesulfovibrio_indicus/
# ...                                                                                    ...
# 3417591                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
# 3417592                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
# 3417593                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
# 3417594                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
# 3417595                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
#
#                             sequence seq_length           GC_content      Q  \
# 0        pseudodesulfovibrio_indicus    3966573    0,634883563216913  -20,0
# 1        pseudodesulfovibrio_indicus    3966573    0,634883563216913  -19,0
# 2        pseudodesulfovibrio_indicus    3966573    0,634883563216913  -18,0
# 3        pseudodesulfovibrio_indicus    3966573    0,634883563216913  -17,0
# 4        pseudodesulfovibrio_indicus    3966573    0,634883563216913  -16,0
# ...                              ...        ...                  ...    ...
# 3417591      zymomonas_sp._segment_3     640617  0,45795381639887794   16,0
# 3417592      zymomonas_sp._segment_3     640617  0,45795381639887794   17,0
# 3417593      zymomonas_sp._segment_3     640617  0,45795381639887794   18,0
# 3417594      zymomonas_sp._segment_3     640617  0,45795381639887794   19,0
# 3417595      zymomonas_sp._segment_3     640617  0,45795381639887794   20,0
#
#                       Tau(Q)                D(Q)           r_squared  \
# 0         -58,22372404009182    2,77255828762342   0,998439748513986
# 1         -55,31755996878647  2,7658779984393234  0,9984547716999835
# 2         -52,41184580682713  2,7585182003593225  0,9984714685532762
# 3        -49,506696847686705   2,750372047093706  0,9984901100821286
# 4        -46,602267713291056  2,7413098654877093  0,9985110304927113
# ...                      ...                 ...                 ...
# 3417591   24,041505273994705  1,6027670182663136  0,9983998418704588
# 3417592   25,564688499910517  1,5977930312444073  0,9983302561291089
# 3417593    27,08653137280582  1,5933253748709306  0,9982699578190471
# 3417594   28,607184008911975  1,5892880004951098  0,9982175466913437
# 3417595   30,126769923329796  1,5856194696489367  0,9981718483610235
#
#                    Delta_Dq
# 0        1,2478087067971309
# 1        1,2478087067971309
# 2        1,2478087067971309
# 3        1,2478087067971309
# 4        1,2478087067971309
# ...                     ...
# 3417591  1,2856818438370474
# 3417592  1,2856818438370474
# 3417593  1,2856818438370474
# 3417594  1,2856818438370474
# 3417595  1,2856818438370474
#
# [3417596 rows x 10 columns]

# %% [markdown]
# ## Data Preparation

# %%
df_composite_key_bacteria_0_35k = df_bacteria_0_35k.drop_duplicates(subset=['GC_content', 'Delta_Dq', 'sequence'])
df_composite_key_bacteria_0_35k.shape
# Out:
# (135104, 10)

# %%
df_composite_key_bacteria_0_35k = df_composite_key_bacteria_0_35k.replace({',': '.'}, regex=True)
df_composite_key_bacteria_0_35k = df_composite_key_bacteria_0_35k.apply(pd.to_numeric, errors='ignore')
# Out:
# C:\Users\Diego\AppData\Local\Temp\ipykernel_52308\2150735517.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_composite_key_bacteria_0_35k = df_composite_key_bacteria_0_35k.apply(pd.to_numeric, errors='ignore')

# %%
df_composite_key_bacteria_35k_52k = df_bacteria_35k_52k.drop_duplicates(subset=['GC_content', 'Delta_Dq', 'sequence'])
df_composite_key_bacteria_35k_52k.shape
# Out:
# (69084, 10)

# %%
df_composite_key_bacteria_35k_52k = df_composite_key_bacteria_35k_52k.replace({',': '.'}, regex=True)
df_composite_key_bacteria_35k_52k = df_composite_key_bacteria_35k_52k.apply(pd.to_numeric, errors='ignore')
# Out:
# C:\Users\Diego\AppData\Local\Temp\ipykernel_52308\262946745.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_composite_key_bacteria_35k_52k = df_composite_key_bacteria_35k_52k.apply(pd.to_numeric, errors='ignore')

# %%
df_composite_key_bacteria = pd.concat([df_composite_key_bacteria_0_35k, df_composite_key_bacteria_35k_52k], ignore_index=True)
print(df_composite_key_bacteria.shape)
df_composite_key_bacteria
# Out:
# (204188, 10)
#                                name  \
# 0       Abditibacterium_utsteinense
# 1       Abditibacterium_utsteinense
# 2       Abditibacterium_utsteinense
# 3       Abditibacterium_utsteinense
# 4             Abiotrophia_defectiva
# ...                             ...
# 204183            Zymomonas_mobilis
# 204184                Zymomonas_sp.
# 204185                Zymomonas_sp.
# 204186                Zymomonas_sp.
# 204187                Zymomonas_sp.
#
#                                                                                       url  \
# 0       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 1       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 2       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 3       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 4             https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_defectiva/
# ...                                                                                   ...
# 204183            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_mobilis/
# 204184                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
# 204185                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
# 204186                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
# 204187                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
#
#                                      sequence  seq_length  GC_content     Q  \
# 0                 abditibacterium_utsteinense     3606331    0.542684 -20.0
# 1       abditibacterium_utsteinense_segment_1     1202110    0.544933 -20.0
# 2       abditibacterium_utsteinense_segment_2     1202110    0.543961 -20.0
# 3       abditibacterium_utsteinense_segment_3     1202110    0.539157 -20.0
# 4                       abiotrophia_defectiva     2043439    0.469444 -20.0
# ...                                       ...         ...         ...   ...
# 204183            zymomonas_mobilis_segment_3      685454    0.465150 -20.0
# 204184                          zymomonas_sp.     1921851    0.458903 -20.0
# 204185                zymomonas_sp._segment_1      640617    0.459140 -20.0
# 204186                zymomonas_sp._segment_2      640617    0.459615 -20.0
# 204187                zymomonas_sp._segment_3      640617    0.457954 -20.0
#
#            Tau(Q)      D(Q)  r_squared  Delta_Dq
# 0      -72.664655  3.460222   0.969815  2.136054
# 1      -67.746182  3.226009   0.942334  1.909285
# 2      -66.961196  3.188628   0.962745  1.863879
# 3      -68.399248  3.257107   0.933928  1.927774
# 4      -51.983359  2.475398   0.996970  0.811359
# ...           ...       ...        ...       ...
# 204183 -60.810954  2.895760   0.994370  1.295974
# 204184 -63.408908  3.019472   0.996031  1.433338
# 204185 -62.520256  2.977155   0.988585  1.401800
# 204186 -61.116224  2.910296   0.993888  1.329194
# 204187 -60.297328  2.871301   0.996142  1.285682
#
# [204188 rows x 10 columns]

# %%
# if 'sequence' ends in 'segment_1' -> df_composite_key_bacteria['segment'] = 1
# if 'sequence' ends in 'segment_2' -> df_composite_key_bacteria['segment'] = 2
# if 'sequence' ends in 'segment_3' -> df_composite_key_bacteria['segment'] = 3
# else -> df_composite_key_bacteria['segment'] = -1

df_composite_key_bacteria['segment'] = np.where(
    df_composite_key_bacteria['sequence'].str.endswith('segment_1'), 1,
    np.where(
        df_composite_key_bacteria['sequence'].str.endswith('segment_2'), 2,
        np.where(
            df_composite_key_bacteria['sequence'].str.endswith('segment_3'), 3,
            -1  # default value if none of the conditions are met
        )
    )
)

# %%
df_composite_key_bacteria
# Out:
#                                name  \
# 0       Abditibacterium_utsteinense
# 1       Abditibacterium_utsteinense
# 2       Abditibacterium_utsteinense
# 3       Abditibacterium_utsteinense
# 4             Abiotrophia_defectiva
# ...                             ...
# 204183            Zymomonas_mobilis
# 204184                Zymomonas_sp.
# 204185                Zymomonas_sp.
# 204186                Zymomonas_sp.
# 204187                Zymomonas_sp.
#
#                                                                                       url  \
# 0       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 1       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 2       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 3       https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 4             https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_defectiva/
# ...                                                                                   ...
# 204183            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_mobilis/
# 204184                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
# 204185                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
# 204186                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
# 204187                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
#
#                                      sequence  seq_length  GC_content     Q  \
# 0                 abditibacterium_utsteinense     3606331    0.542684 -20.0
# 1       abditibacterium_utsteinense_segment_1     1202110    0.544933 -20.0
# 2       abditibacterium_utsteinense_segment_2     1202110    0.543961 -20.0
# 3       abditibacterium_utsteinense_segment_3     1202110    0.539157 -20.0
# 4                       abiotrophia_defectiva     2043439    0.469444 -20.0
# ...                                       ...         ...         ...   ...
# 204183            zymomonas_mobilis_segment_3      685454    0.465150 -20.0
# 204184                          zymomonas_sp.     1921851    0.458903 -20.0
# 204185                zymomonas_sp._segment_1      640617    0.459140 -20.0
# 204186                zymomonas_sp._segment_2      640617    0.459615 -20.0
# 204187                zymomonas_sp._segment_3      640617    0.457954 -20.0
#
#            Tau(Q)      D(Q)  r_squared  Delta_Dq  segment
# 0      -72.664655  3.460222   0.969815  2.136054       -1
# 1      -67.746182  3.226009   0.942334  1.909285        1
# 2      -66.961196  3.188628   0.962745  1.863879        2
# 3      -68.399248  3.257107   0.933928  1.927774        3
# 4      -51.983359  2.475398   0.996970  0.811359       -1
# ...           ...       ...        ...       ...      ...
# 204183 -60.810954  2.895760   0.994370  1.295974        3
# 204184 -63.408908  3.019472   0.996031  1.433338       -1
# 204185 -62.520256  2.977155   0.988585  1.401800        1
# 204186 -61.116224  2.910296   0.993888  1.329194        2
# 204187 -60.297328  2.871301   0.996142  1.285682        3
#
# [204188 rows x 11 columns]

# %%
df_full_genomes_bacteria = df_composite_key_bacteria[df_composite_key_bacteria['segment'] == -1]
df_full_genomes_bacteria.shape
# Out:
# (51047, 11)

# %% [markdown]
# ## DeltaDq vs GC

# %%
plt.scatter(
    x=df_full_genomes_bacteria['GC_content'],
    y=df_full_genomes_bacteria['Delta_Dq'],
    s=10,
    c='blue',
    alpha=0.045
)

plt.title(r'$\Delta Dq$ vs GC content - Bacteria')
plt.xlabel('GC content')
plt.ylabel(r'$\Delta Dq$')

plt.xlim(0.2, 0.75)

plt.show()

# %% [markdown]
# ## Taxonomy

# %%
df_tax_bacteria = pd.read_json(PATH_TAXONOMY_BACTERIA / 'taxonomy_bacteria.json', dtype=str)
df_tax_bacteria = df_tax_bacteria.rename(columns={'organism_name': 'name'})
df_tax_bacteria
# Out:
#                                                                        url  \
# 0      https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=1960156
# 1      https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=2291993
# 2      https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=2926319
# 3        https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=46125
# 4      https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=2718527
# ...                                                                    ...
# 52628  https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=1131287
# 52629  https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=1131288
# 52630  https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=1131289
# 52631  https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=1131282
# 52632  https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=1131290
#
#                                        name             no rank superkingdom  \
# 0               Abditibacterium_utsteinense  cellular organisms     Bacteria
# 1                      Absiella_sp._AM09-45  cellular organisms     Bacteria
# 2                Absicoccus_sp._CLA-KB-P134  cellular organisms     Bacteria
# 3                     Abiotrophia_defectiva                 nan          nan
# 4                            Absicoccus_sp.  cellular organisms     Bacteria
# ...                                     ...                 ...          ...
# 52628  zeta_proteobacterium_SCGC_AB-602-C20  cellular organisms     Bacteria
# 52629  zeta_proteobacterium_SCGC_AB-602-E04  cellular organisms     Bacteria
# 52630  zeta_proteobacterium_SCGC_AB-604-B04  cellular organisms     Bacteria
# 52631  zeta_proteobacterium_SCGC_AB-133-G06  cellular organisms     Bacteria
# 52632  zeta_proteobacterium_SCGC_AB-604-O16  cellular organisms     Bacteria
#
#          kingdom            phylum               class               order  \
# 0      Bacillati  Abditibacteriota     Abditibacteriia   Abditibacteriales
# 1      Bacillati         Bacillota    Erysipelotrichia  Erysipelotrichales
# 2      Bacillati         Bacillota    Erysipelotrichia  Erysipelotrichales
# 3            nan               nan                 nan                 nan
# 4      Bacillati         Bacillota    Erysipelotrichia  Erysipelotrichales
# ...          ...               ...                 ...                 ...
# 52628        nan    Pseudomonadota  Zetaproteobacteria                 nan
# 52629        nan    Pseudomonadota  Zetaproteobacteria                 nan
# 52630        nan    Pseudomonadota  Zetaproteobacteria                 nan
# 52631        nan    Pseudomonadota  Zetaproteobacteria                 nan
# 52632        nan    Pseudomonadota  Zetaproteobacteria                 nan
#
#                     family            genus clade species group  \
# 0       Abditibacteriaceae  Abditibacterium   nan           nan
# 1      Erysipelotrichaceae   Amedibacterium   nan           nan
# 2      Erysipelotrichaceae       Absicoccus   nan           nan
# 3                      nan              nan   nan           nan
# 4      Erysipelotrichaceae       Absicoccus   nan           nan
# ...                    ...              ...   ...           ...
# 52628                  nan              nan   nan           nan
# 52629                  nan              nan   nan           nan
# 52630                  nan              nan   nan           nan
# 52631                  nan              nan   nan           nan
# 52632                  nan              nan   nan           nan
#
#       species subgroup species suborder subclass subfamily tribe subspecies  \
# 0                  nan     nan      nan      nan       nan   nan        nan
# 1                  nan     nan      nan      nan       nan   nan        nan
# 2                  nan     nan      nan      nan       nan   nan        nan
# 3                  nan     nan      nan      nan       nan   nan        nan
# 4                  nan     nan      nan      nan       nan   nan        nan
# ...                ...     ...      ...      ...       ...   ...        ...
# 52628              nan     nan      nan      nan       nan   nan        nan
# 52629              nan     nan      nan      nan       nan   nan        nan
# 52630              nan     nan      nan      nan       nan   nan        nan
# 52631              nan     nan      nan      nan       nan   nan        nan
# 52632              nan     nan      nan      nan       nan   nan        nan
#
#       strain
# 0        nan  nan
# 1        nan  nan
# 2        nan  nan
# 3        nan  nan
# 4        nan  nan
# ...      ...  ...
# 52628    nan  nan
# 52629    nan  nan
# 52630    nan  nan
# 52631    nan  nan
# 52632    nan  nan
#
# [52633 rows x 21 columns]

# %%
df_combined_bacteria = pd.merge(df_full_genomes_bacteria, df_tax_bacteria, on='name', how='left')
df_combined_bacteria
# Out:
#                               name  \
# 0      Abditibacterium_utsteinense
# 1            Abiotrophia_defectiva
# 2                  Abiotrophia_sp.
# 3        Abiotrophia_sp._HMSC24B09
# 4                 Absicoccus_porci
# ...                            ...
# 51042                  Zwartia_sp.
# 51043                 Zwartia_vadi
# 51044            Zymobacter_palmae
# 51045            Zymomonas_mobilis
# 51046                Zymomonas_sp.
#
#                                                                                    url_x  \
# 0      https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abditibacterium_utsteinense/
# 1            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_defectiva/
# 2                  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp./
# 3        https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Abiotrophia_sp._HMSC24B09/
# 4                 https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Absicoccus_porci/
# ...                                                                                  ...
# 51042                  https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zwartia_sp./
# 51043                 https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zwartia_vadi/
# 51044            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymobacter_palmae/
# 51045            https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_mobilis/
# 51046                https://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Zymomonas_sp./
#
#                           sequence  seq_length  GC_content     Q     Tau(Q)  \
# 0      abditibacterium_utsteinense     3606331    0.542684 -20.0 -72.664655
# 1            abiotrophia_defectiva     2043439    0.469444 -20.0 -51.983359
# 2                  abiotrophia_sp.     2016058    0.468279 -20.0 -51.421689
# 3        abiotrophia_sp._hmsc24b09     2020784    0.465602 -20.0 -51.248092
# 4                 absicoccus_porci     2222132    0.386083 -20.0 -61.226997
# ...                            ...         ...         ...   ...        ...
# 51042                  zwartia_sp.     3447573    0.522330 -20.0 -54.883937
# 51043                 zwartia_vadi     3232556    0.516148 -20.0 -55.822353
# 51044            zymobacter_palmae     2972948    0.560158 -20.0 -54.407879
# 51045            zymomonas_mobilis     2056363    0.463281 -20.0 -62.840417
# 51046                zymomonas_sp.     1921851    0.458903 -20.0 -63.408908
#
#            D(Q)  r_squared  Delta_Dq  segment  \
# 0      3.460222   0.969815  2.136054       -1
# 1      2.475398   0.996970  0.811359       -1
# 2      2.448652   0.997900  0.765295       -1
# 3      2.440385   0.998546  0.752920       -1
# 4      2.915571   0.991482  1.339399       -1
# ...         ...        ...       ...      ...
# 51042  2.613521   0.996992  0.857123       -1
# 51043  2.658207   0.995042  0.922856       -1
# 51044  2.590851   0.997957  0.975079       -1
# 51045  2.992401   0.996317  1.396024       -1
# 51046  3.019472   0.996031  1.433338       -1
#
#                                                                      url_y  \
# 0      https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=1960156
# 1        https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=46125
# 2        https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=76631
# 3      https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=1581061
# 4      https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=2486576
# ...                                                                    ...
# 51042  https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=2978004
# 51043  https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=3058168
# 51044    https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=33074
# 51045      https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=542
# 51046  https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=2068624
#
#                   no rank superkingdom    kingdom            phylum  \
# 0      cellular organisms     Bacteria  Bacillati  Abditibacteriota
# 1                     nan          nan        nan               nan
# 2      cellular organisms     Bacteria  Bacillati         Bacillota
# 3      cellular organisms     Bacteria  Bacillati         Bacillota
# 4      cellular organisms     Bacteria  Bacillati         Bacillota
# ...                   ...          ...        ...               ...
# 51042  cellular organisms     Bacteria        nan    Pseudomonadota
# 51043  cellular organisms     Bacteria        nan    Pseudomonadota
# 51044                 nan          nan        nan               nan
# 51045                 nan          nan        nan               nan
# 51046  cellular organisms     Bacteria        nan    Pseudomonadota
#
#                      class               order               family  \
# 0          Abditibacteriia   Abditibacteriales   Abditibacteriaceae
# 1                      nan                 nan                  nan
# 2                  Bacilli     Lactobacillales        Aerococcaceae
# 3                  Bacilli     Lactobacillales        Aerococcaceae
# 4         Erysipelotrichia  Erysipelotrichales  Erysipelotrichaceae
# ...                    ...                 ...                  ...
# 51042   Betaproteobacteria     Burkholderiales       Alcaligenaceae
# 51043   Betaproteobacteria     Burkholderiales       Alcaligenaceae
# 51044                  nan                 nan                  nan
# 51045                  nan                 nan                  nan
# 51046  Alphaproteobacteria    Sphingomonadales       Zymomonadaceae
#
#                  genus clade species group species subgroup species suborder  \
# 0      Abditibacterium   nan           nan              nan     nan      nan
# 1                  nan   nan           nan              nan     nan      nan
# 2          Abiotrophia   nan           nan              nan     nan      nan
# 3          Abiotrophia   nan           nan              nan     nan      nan
# 4           Absicoccus   nan           nan              nan     nan      nan
# ...                ...   ...           ...              ...     ...      ...
# 51042          Zwartia   nan           nan              nan     nan      nan
# 51043          Zwartia   nan           nan              nan     nan      nan
# 51044              nan   nan           nan              nan     nan      nan
# 51045              nan   nan           nan              nan     nan      nan
# 51046        Zymomonas   nan           nan              nan     nan      nan
#
#       subclass subfamily tribe subspecies strain
# 0          nan       nan   nan        nan    nan  nan
# 1          nan       nan   nan        nan    nan  nan
# 2          nan       nan   nan        nan    nan  nan
# 3          nan       nan   nan        nan    nan  nan
# 4          nan       nan   nan        nan    nan  nan
# ...        ...       ...   ...        ...    ...  ...
# 51042      nan       nan   nan        nan    nan  nan
# 51043      nan       nan   nan        nan    nan  nan
# 51044      nan       nan   nan        nan    nan  nan
# 51045      nan       nan   nan        nan    nan  nan
# 51046      nan       nan   nan        nan    nan  nan
#
# [51047 rows x 31 columns]

# %%
df_combined_bacteria = df_combined_bacteria.drop('', axis=1)
df_combined_bacteria.shape
# Out:
# (51047, 30)

# %%
df_combined_bacteria.columns
# Out:
# Index(['name', 'url_x', 'sequence', 'seq_length', 'GC_content', 'Q', 'Tau(Q)',
#        'D(Q)', 'r_squared', 'Delta_Dq', 'segment', 'url_y', 'no rank',
#        'superkingdom', 'kingdom', 'phylum', 'class', 'order', 'family',
#        'genus', 'clade', 'species group', 'species subgroup', 'species',
#        'suborder', 'subclass', 'subfamily', 'tribe', 'subspecies', 'strain'],
#       dtype='object')

# %%
df_combined_bacteria.columns[-17:]
# Out:
# Index(['superkingdom', 'kingdom', 'phylum', 'class', 'order', 'family',
#        'genus', 'clade', 'species group', 'species subgroup', 'species',
#        'suborder', 'subclass', 'subfamily', 'tribe', 'subspecies', 'strain'],
#       dtype='object')

# %%
print(df_combined_bacteria.shape)
df_combined_bacteria.isna().sum()
# Out:
# (51047, 30)
# name                  0
# url_x                 0
# sequence              0
# seq_length            0
# GC_content            0
# Q                     0
# Tau(Q)                0
# D(Q)                  0
# r_squared             0
# Delta_Dq              0
# segment               0
# url_y               111
# no rank             111
# superkingdom        111
# kingdom             111
# phylum              111
# class               111
# order               111
# family              111
# genus               111
# clade               111
# species group       111
# species subgroup    111
# species             111
# suborder            111
# subclass            111
# subfamily           111
# tribe               111
# subspecies          111
# strain              111
# dtype: int64

# %%
taxonomy_columns = ['superkingdom', 'kingdom', 'phylum', 'class', 'order', 'family',
       'genus', 'clade', 'species group', 'species subgroup', 'species',
       'suborder', 'subclass', 'subfamily', 'tribe', 'subspecies', 'strain']
print(len(taxonomy_columns))
# Out:
# 17

# %%
df_combined_bacteria[taxonomy_columns] = df_combined_bacteria[taxonomy_columns].apply(lambda col: col.mask(col.isna(), pd.NA))
df_combined_bacteria[taxonomy_columns] = df_combined_bacteria[taxonomy_columns].replace('nan', pd.NA)

# %%
df_combined_bacteria['superkingdom'].unique()
# Out:
# array(['Bacteria', <NA>], dtype=object)

# %%
df_combined_bacteria['kingdom'].unique()
# Out:
# array(['Bacillati', <NA>, 'Pseudomonadati'], dtype=object)

# %%
# Calculate unique counts for each column
unique_counts = {column: df_combined_bacteria[column].nunique() for column in taxonomy_columns}

# Convert the dictionary to a DataFrame for better readability
unique_counts_df = pd.DataFrame(list(unique_counts.items()), columns=['Column', 'Unique Count'])

# Display the DataFrame
unique_counts
# Out:
# {'superkingdom': 1,
#  'kingdom': 2,
#  'phylum': 73,
#  'class': 121,
#  'order': 284,
#  'family': 719,
#  'genus': 3569,
#  'clade': 21,
#  'species group': 61,
#  'species subgroup': 19,
#  'species': 8,
#  'suborder': 4,
#  'subclass': 2,
#  'subfamily': 1,
#  'tribe': 2,
#  'subspecies': 0,
#  'strain': 1}

# %%
taxonomic_rank = 'species group'
frequent_taxas = df_combined_bacteria[taxonomic_rank].value_counts()
N = 8
categories = frequent_taxas.index[:N]
print(len(frequent_taxas))
frequent_taxas[:15]
# Out:
# 61
# species group
# Bacillus cereus group                            267
# Enterobacter cloacae complex                     184
# Acinetobacter calcoaceticus/baumannii complex     61
# Citrobacter freundii complex                      34
# Pseudomonas fluorescens group                     26
# Mycobacterium simiae complex                      17
# Burkholderia cepacia complex                      16
# Pseudomonas syringae group                        15
# Stenotrophomonas maltophilia group                14
# Pseudomonas putida group                          12
# Streptomyces griseus group                        12
# Streptomyces aurantiacus group                    11
# Streptomyces violaceusniger group                 11
# 16SrI (Aster yellows group)                       10
# Ralstonia solanacearum species complex             9
# Name: count, dtype: int64

# %%
# Filter the DataFrame to include only the desired categories
df_filtered = df_combined_bacteria[df_combined_bacteria[taxonomic_rank].isin(categories)]

# Number of categories to plot
# N = len(categories)

# Generate a color palette with N distinct colors
colors = sns.color_palette('hls', N)

plt.figure(figsize=(10, 7.5))

legend_handles = []

# Loop over each unique category in the filtered DataFrame
for i, (category, group) in enumerate(df_filtered.groupby(taxonomic_rank)):
    num_points = len(group)

    if not category:
        continue

    plt.scatter(    
        x=group['GC_content'],
        y=group['Delta_Dq'],
        s=10,
        color=colors[i],  # Assign a unique color from the color palette
        alpha=0.5,
        label=category
    )

    # Create a custom legend handle with full opacity
    legend_handle = Line2D(
        [0], [0],
        marker='o',
        color='w',
        label=f'{category} ({num_points})',
        markerfacecolor=colors[i],
        markersize=10
    )
    legend_handles.append(legend_handle)

# Add plot title and labels
plt.title(f'$\Delta Dq$ vs GC content by {taxonomic_rank.capitalize()} (top {N}) - Bacteria')
plt.xlabel('GC content')
plt.ylabel(r'$\Delta Dq$')

# Show legend
plt.legend(handles=legend_handles)

# Display plot
plt.show()
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\D'
# <>:42: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Diego\AppData\Local\Temp\ipykernel_52308\1155985172.py:42: SyntaxWarning: invalid escape sequence '\D'
#   plt.title(f'$\Delta Dq$ vs GC content by {taxonomic_rank.capitalize()} (top {N}) - Bacteria')

# %%
# categories = df_combined_bacteria[taxonomic_rank].dropna().unique()
categories = frequent_taxas.index[:N]
N = len(categories)

# Generate a color palette with enough colors for all categories
colors = sns.color_palette('hls', N)

# Create a dictionary to map categories to colors
category_colors = dict(zip(categories, colors))

# Initialize the legend handles list
legend_handles = []

# Create the main plot
fig, ax = plt.subplots(figsize=(8, 6))

# Loop over each unique category and plot separately
for category in categories:
    group = df_combined_bacteria[df_combined_bacteria[taxonomic_rank] == category]
    num_points = len(group)
    
    # Plot the data points for the current category
    ax.scatter(
        x=group['GC_content'],
        y=group['Delta_Dq'],
        s=10,
        color=category_colors[category],
        alpha=0.15
    )
    
    # Create a custom legend handle
    legend_handle = Line2D(
        [0], [0],
        marker='o',
        color='w',
        label=f'{category} ({num_points})',
        markerfacecolor=category_colors[category],
        markersize=10
    )
    legend_handles.append(legend_handle)

# Add plot title and labels
ax.set_title(f'$\Delta Dq$ vs GC content by {taxonomic_rank} - Bacteria')
ax.set_xlabel('GC content')
ax.set_ylabel(r'$\Delta Dq$')

# Display the main plot without the legend
plt.show()

# Create a separate figure for the legend
fig_leg = plt.figure(figsize=(8, 6))
fig_leg.legend(
    handles=legend_handles,
    title=taxonomic_rank,
    loc='center',
    frameon=False
)
fig_leg.canvas.draw()

# Remove axes and ticks from the legend figure
plt.axis('off')

# Display the legend figure
plt.show()
# Out:
# <>:43: SyntaxWarning: invalid escape sequence '\D'
# <>:43: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Diego\AppData\Local\Temp\ipykernel_52308\2664265560.py:43: SyntaxWarning: invalid escape sequence '\D'
#   ax.set_title(f'$\Delta Dq$ vs GC content by {taxonomic_rank} - Bacteria')

# %% [markdown]
# 'kingdom', 'phylum', 'class', 'order', 'family',
# 'genus', 'clade', 'species group', 'species subgroup',
# 'species', 'suborder', 'subclass', 'subfamily', 'tribe',
# 'subspecies', 'strain'

# %%
taxonomic_rank = 'clade'

# Calculate the frequency counts
frequency_counts = df_combined_bacteria[taxonomic_rank].value_counts()

# Define the number of top categories you want to plot individually
N = 15  # You can change this number to suit your needs

# Get the top N categories
top_categories = frequency_counts.index[:N]

# Total number of data points (excluding NaNs)
total_points = df_combined_bacteria[taxonomic_rank].notna().sum()
print(frequency_counts.shape)
frequency_counts[:10]
# Out:
# (21,)
# clade
# FCB group                                           3974
# Cyanobacteriota/Melainabacteria group               1278
# PVC group                                            426
# Bacteria candidate phyla                             129
# ant, tsetse, mealybug, aphid, etc. endosymbionts      28
# delta/epsilon subdivisions                            17
# sulfur-oxidizing symbionts                            11
# Luna-1 subcluster                                     10
# Nitrospinota/Tectimicrobiota group                     6
# Caldisericota/Cryosericota group                       5
# Name: count, dtype: int64

# %%
# Assuming 'N' and 'top_categories' have been defined earlier in your code
# Generate a list of high-contrast colors
colors = sns.color_palette('Set3', N)

# Define the neutral background color
background_color = 'gray'

# Iterate over each of the top categories to create individual plots
for i, category in enumerate(top_categories):
    plt.figure(figsize=(8, 6))
    
    # Filter data for the current category
    category_data = df_combined_bacteria[df_combined_bacteria[taxonomic_rank] == category]
    num_points = len(category_data)
    
    # Plot all data points in the background color (excluding the current category)
    background_data = df_combined_bacteria[df_combined_bacteria[taxonomic_rank] != category]
    plt.scatter(
        x=background_data['GC_content'],
        y=background_data['Delta_Dq'],
        s=10,
        color=background_color,
        alpha=0.1,
        label='_nolegend_'  # Prevent automatic legend entry
    )
    
    # Highlight the current category with a distinct color
    plt.scatter(
        x=category_data['GC_content'],
        y=category_data['Delta_Dq'],
        s=10,
        color='blue',  # Use 'colors[i]' if you want different colors per category
        alpha=0.1,
        label='_nolegend_'  # Prevent automatic legend entry
    )
    
    # Create custom legend handles with alpha=1 (fully opaque)
    legend_handles = [
        Line2D(
            [0], [0],
            marker='o',
            color='w',
            label=f'Others ({total_points - num_points})',
            markerfacecolor=background_color,
            markersize=10,
            alpha=1  # Ensure full opacity
        ),
        Line2D(
            [0], [0],
            marker='o',
            color='w',
            label=f'{category} ({num_points})',
            markerfacecolor='blue',  # Or colors[i] if using the color palette
            markersize=10,
            alpha=1  # Ensure full opacity
        )
    ]
    
    # Add plot title and labels
    plt.title(f'$\Delta Dq$ vs GC content for {taxonomic_rank}: {category} - Bacteria')
    plt.xlabel('GC content')
    plt.ylabel(r'$\Delta Dq$')
    
    # Show legend with custom handles
    plt.legend(handles=legend_handles, title=taxonomic_rank)
    
    # Optionally, save the plot to a file
    # plt.savefig(f'plot_{category}.png')
    
    # Display plot
    plt.show()
# Out:
# <>:60: SyntaxWarning: invalid escape sequence '\D'
# <>:60: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Diego\AppData\Local\Temp\ipykernel_52308\4145198275.py:60: SyntaxWarning: invalid escape sequence '\D'
#   plt.title(f'$\Delta Dq$ vs GC content for {taxonomic_rank}: {category} - Bacteria')

# %% [markdown]
# # Stacked Histograms

# %%
df_combined_bacteria.shape
# Out:
# (51047, 30)

# %%
df_combined_bacteria.columns[-16:]
# Out:
# Index(['kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'clade',
#        'species group', 'species subgroup', 'species', 'suborder', 'subclass',
#        'subfamily', 'tribe', 'subspecies', 'strain'],
#       dtype='object')

# %%
taxonomic_rank = 'species group'
N = 10
frequency_counts = df_combined_bacteria[taxonomic_rank].value_counts()

# Get the top N categories based on frequency
top_categories = frequency_counts.index[:N]

# Filter the DataFrame to include only the desired categories
df_filtered = df_combined_bacteria[df_combined_bacteria[taxonomic_rank].isin(top_categories)]
print(len(frequency_counts))
frequency_counts[:15]
# Out:
# 61
# species group
# Bacillus cereus group                            267
# Enterobacter cloacae complex                     184
# Acinetobacter calcoaceticus/baumannii complex     61
# Citrobacter freundii complex                      34
# Pseudomonas fluorescens group                     26
# Mycobacterium simiae complex                      17
# Burkholderia cepacia complex                      16
# Pseudomonas syringae group                        15
# Stenotrophomonas maltophilia group                14
# Pseudomonas putida group                          12
# Streptomyces griseus group                        12
# Streptomyces aurantiacus group                    11
# Streptomyces violaceusniger group                 11
# 16SrI (Aster yellows group)                       10
# Ralstonia solanacearum species complex             9
# Name: count, dtype: int64

# %%
# Define the number of bins for GC content
num_bins = 20  # Adjust this number as needed

# Create bins for GC content using numpy's linspace function
gc_content_bins = np.linspace(
    0,
    1,
    num_bins + 1
)

# Bin the 'GC_content' data and assign bin labels
df_filtered['GC_content_bin'] = pd.cut(
    df_filtered['GC_content'],
    bins=gc_content_bins,
    include_lowest=True
)

# Remove any rows with NaN values in 'taxonomic_rank' or 'GC_content_bin'
df_filtered = df_filtered.dropna(subset=[taxonomic_rank, 'GC_content_bin'])

# Create a crosstab of counts per GC content bin and taxonomic rank
crosstab = pd.crosstab(
    df_filtered['GC_content_bin'],  # Rows: GC content bins
    df_filtered[taxonomic_rank]     # Columns: Taxonomic categories
)
# Out:
# C:\Users\Diego\AppData\Local\Temp\ipykernel_52308\1020088050.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['GC_content_bin'] = pd.cut(

# %%
taxon_counts = df_filtered[taxonomic_rank].value_counts()
legend_labels = {
    taxon: f"{taxon} ({count})" for taxon, count in taxon_counts.items()
}

# Generate a color palette with N distinct colors
colors = sns.color_palette('hls', N)

# Set the figure size
plt.figure(figsize=(8, 6))

# Plot the stacked bar chart
ax = crosstab.plot(
    kind='bar',
    stacked=True,
    figsize=(8, 7.5),
    color=colors,  # Use the custom color palette
    width=0.7  # Set the bar width to 1.0 to make bars touch
)

# Update the legend with formatted labels
handles, labels = ax.get_legend_handles_labels()
formatted_labels = [legend_labels[label] for label in labels]
ax.legend(handles, formatted_labels)# , title=f'{taxonomic_rank.capitalize()}')

# Customize the plot
plt.title(f'Counts by GC Content Bins and Top {N} {taxonomic_rank.capitalize()} - Bacteria')
plt.xlabel('GC Content Bins')
plt.ylabel('Number of Organisms')
plt.xticks(rotation=45, ha='right')

# Add a legend with a title and the number of points
# plt.legend(title=f'{taxonomic_rank.capitalize()}')# ({ len(df_filtered)})') })')

# Adjust layout to prevent clipping of tick-labels
# plt.tight_layout()

plt.show()
